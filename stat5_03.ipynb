# %%
import pandas as pd

# Load your data
sheet_url = 'https://docs.google.com/spreadsheets/d/1cv7bvwn7Kg7TxvOaleEcaM7e3SgEfM39G8K5xpk0yT8/export?gid=581234657&format=csv'
df = pd.read_csv(sheet_url)

# Step 1: Filter for D section only
d_section = 'D: Tu 08:30AM-09:35AM (Antonio)'
df_d = df[df['Section you attended:'] == d_section]

# Step 2: Group by email and aggregate name and count
result = (
    df_d
    .groupby('Email Address')
    .agg(
        Count=('Email Address', 'size')  
        )
    .reset_index()
)

# Show results
print(result)
# Out:
#         Email Address  Count
# 0   abjsheph@ucsc.edu      5
# 1   agfitzpa@ucsc.edu      5
# 2   alrsingh@ucsc.edu      5
# 3   amsussma@ucsc.edu      6
# 4   babolano@ucsc.edu      4
# 5   bvasque8@ucsc.edu      3
# 6   cchannel@ucsc.edu      6
# 7   chrwhipp@ucsc.edu      4
# 8   dewthoma@ucsc.edu      4
# 9     egruiz@ucsc.edu      4
# 10  emangapo@ucsc.edu      4
# 11     gpugh@ucsc.edu      1
# 12     idas5@ucsc.edu      4
# 13    jklund@ucsc.edu      3
# 14  jmcharle@ucsc.edu      1
# 15   kgpayne@ucsc.edu      2
# 16     ldbui@ucsc.edu      5
# 17      llta@ucsc.edu      1
# 18  lyrcorfi@ucsc.edu      5
# 19  miapablo@ucsc.edu      4
# 20    mitagi@ucsc.edu      1
# 21  mmart318@ucsc.edu      6
# 22  nagcarri@ucsc.edu      5
# 23  nfelixar@ucsc.edu      4
# 24  nmacchie@ucsc.edu      6
# 25  nrondeau@ucsc.edu      6
# 26   qpgiang@ucsc.edu      6
# 27   rfclark@ucsc.edu      2
# 28  rolacost@ucsc.edu      1
# 29   sagburt@ucsc.edu      3
# 30    sfilio@ucsc.edu      4
# 31  sflore52@ucsc.edu      6
# 32  shorvath@ucsc.edu      2
# 33  slajeune@ucsc.edu      2
# 34  sobrucke@ucsc.edu      6
# 35  soiaguil@ucsc.edu      5
# 36    toqlam@ucsc.edu      7
# 37   vesouza@ucsc.edu      6
# 38  wikyoung@ucsc.edu      3
