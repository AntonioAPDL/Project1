# %%
.libPaths(c("~/R/libs", .libPaths()))
print(.libPaths())
library(dplyr)
library(prism)
library(raster)
library(sp)

prism_set_dl_dir("/data/muscat_data/jaguir26/project1_ucsc_phd/prism_data")
# Download data (your download already completed, so this might skip again)
get_prism_dailys(type = "ppt", minDate = "2022-12-25", maxDate = "2023-02-25", keepZip = FALSE)
# Out:
# [1] "/home/jaguir26/R/libs"
# [2] "/home/jaguir26/R/x86_64-redhat-linux-gnu-library/4.4"
# [3] "/usr/lib64/R/library"
# [4] "/usr/share/R/library"
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Be sure to set the download folder using `prism_set_dl_dir()`.
#
# Loading required package: sp
#
#
# Attaching package: ‘raster’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#   |                                                                      |   0%
# PRISM_ppt_stable_4kmD2_20221225_bil.zip already exists. Skipping downloading.
#   |=                                                                     |   2%
# PRISM_ppt_stable_4kmD2_20221226_bil.zip already exists. Skipping downloading.
#   |==                                                                    |   3%
# PRISM_ppt_stable_4kmD2_20221227_bil.zip already exists. Skipping downloading.
#   |===                                                                   |   5%
# PRISM_ppt_stable_4kmD2_20221228_bil.zip already exists. Skipping downloading.
#   |====                                                                  |   6%
# PRISM_ppt_stable_4kmD2_20221229_bil.zip already exists. Skipping downloading.
#   |======                                                                |   8%
# PRISM_ppt_stable_4kmD2_20221230_bil.zip already exists. Skipping downloading.
#   |=======                                                               |  10%
# PRISM_ppt_stable_4kmD2_20221231_bil.zip already exists. Skipping downloading.
#   |========                                                              |  11%
# PRISM_ppt_stable_4kmD2_20230101_bil.zip already exists. Skipping downloading.
#   |=========                                                             |  13%
# PRISM_ppt_stable_4kmD2_20230102_bil.zip already exists. Skipping downloading.
#   |==========                                                            |  14%
# PRISM_ppt_stable_4kmD2_20230103_bil.zip already exists. Skipping downloading.
#   |===========                                                           |  16%
# PRISM_ppt_stable_4kmD2_20230104_bil.zip already exists. Skipping downloading.
#   |============                                                          |  17%
# PRISM_ppt_stable_4kmD2_20230105_bil.zip already exists. Skipping downloading.
#   |=============                                                         |  19%
# PRISM_ppt_stable_4kmD2_20230106_bil.zip already exists. Skipping downloading.
#   |==============                                                        |  21%
# PRISM_ppt_stable_4kmD2_20230107_bil.zip already exists. Skipping downloading.
#   |================                                                      |  22%
# PRISM_ppt_stable_4kmD2_20230108_bil.zip already exists. Skipping downloading.
#   |=================                                                     |  24%
# PRISM_ppt_stable_4kmD2_20230109_bil.zip already exists. Skipping downloading.
#   |==================                                                    |  25%
# PRISM_ppt_stable_4kmD2_20230110_bil.zip already exists. Skipping downloading.
#   |===================                                                   |  27%
# PRISM_ppt_stable_4kmD2_20230111_bil.zip already exists. Skipping downloading.
#   |====================                                                  |  29%
# PRISM_ppt_stable_4kmD2_20230112_bil.zip already exists. Skipping downloading.
#   |=====================                                                 |  30%
# PRISM_ppt_stable_4kmD2_20230113_bil.zip already exists. Skipping downloading.
#   |======================                                                |  32%
# PRISM_ppt_stable_4kmD2_20230114_bil.zip already exists. Skipping downloading.
#   |=======================                                               |  33%
# PRISM_ppt_stable_4kmD2_20230115_bil.zip already exists. Skipping downloading.
#   |========================                                              |  35%
# PRISM_ppt_stable_4kmD2_20230116_bil.zip already exists. Skipping downloading.
#   |==========================                                            |  37%
# PRISM_ppt_stable_4kmD2_20230117_bil.zip already exists. Skipping downloading.
#   |===========================                                           |  38%
# PRISM_ppt_stable_4kmD2_20230118_bil.zip already exists. Skipping downloading.
#   |============================                                          |  40%
# PRISM_ppt_stable_4kmD2_20230119_bil.zip already exists. Skipping downloading.
#   |=============================                                         |  41%
# PRISM_ppt_stable_4kmD2_20230120_bil.zip already exists. Skipping downloading.
#   |==============================                                        |  43%
# PRISM_ppt_stable_4kmD2_20230121_bil.zip already exists. Skipping downloading.
#   |===============================                                       |  44%
# PRISM_ppt_stable_4kmD2_20230122_bil.zip already exists. Skipping downloading.
#   |================================                                      |  46%
# PRISM_ppt_stable_4kmD2_20230123_bil.zip already exists. Skipping downloading.
#   |=================================                                     |  48%
# PRISM_ppt_stable_4kmD2_20230124_bil.zip already exists. Skipping downloading.
#   |==================================                                    |  49%
# PRISM_ppt_stable_4kmD2_20230125_bil.zip already exists. Skipping downloading.
#   |====================================                                  |  51%
# PRISM_ppt_stable_4kmD2_20230126_bil.zip already exists. Skipping downloading.
#   |=====================================                                 |  52%
# PRISM_ppt_stable_4kmD2_20230127_bil.zip already exists. Skipping downloading.
#   |======================================                                |  54%
# PRISM_ppt_stable_4kmD2_20230128_bil.zip already exists. Skipping downloading.
#   |=======================================                               |  56%
# PRISM_ppt_stable_4kmD2_20230129_bil.zip already exists. Skipping downloading.
#   |========================================                              |  57%
# PRISM_ppt_stable_4kmD2_20230130_bil.zip already exists. Skipping downloading.
#   |=========================================                             |  59%
# PRISM_ppt_stable_4kmD2_20230131_bil.zip already exists. Skipping downloading.
#   |==========================================                            |  60%
# PRISM_ppt_stable_4kmD2_20230201_bil.zip already exists. Skipping downloading.
#   |===========================================                           |  62%
# PRISM_ppt_stable_4kmD2_20230202_bil.zip already exists. Skipping downloading.
#   |============================================                          |  63%
# PRISM_ppt_stable_4kmD2_20230203_bil.zip already exists. Skipping downloading.
#   |==============================================                        |  65%
# PRISM_ppt_stable_4kmD2_20230204_bil.zip already exists. Skipping downloading.
#   |===============================================                       |  67%
# PRISM_ppt_stable_4kmD2_20230205_bil.zip already exists. Skipping downloading.
#   |================================================                      |  68%
# PRISM_ppt_stable_4kmD2_20230206_bil.zip already exists. Skipping downloading.
#   |=================================================                     |  70%
# PRISM_ppt_stable_4kmD2_20230207_bil.zip already exists. Skipping downloading.
#   |==================================================                    |  71%
# PRISM_ppt_stable_4kmD2_20230208_bil.zip already exists. Skipping downloading.
#   |===================================================                   |  73%
# PRISM_ppt_stable_4kmD2_20230209_bil.zip already exists. Skipping downloading.
#   |====================================================                  |  75%
# PRISM_ppt_stable_4kmD2_20230210_bil.zip already exists. Skipping downloading.
#   |=====================================================                 |  76%
# PRISM_ppt_stable_4kmD2_20230211_bil.zip already exists. Skipping downloading.
#   |======================================================                |  78%
# PRISM_ppt_stable_4kmD2_20230212_bil.zip already exists. Skipping downloading.
#   |========================================================              |  79%
# PRISM_ppt_stable_4kmD2_20230213_bil.zip already exists. Skipping downloading.
#   |=========================================================             |  81%
# PRISM_ppt_stable_4kmD2_20230214_bil.zip already exists. Skipping downloading.
#   |==========================================================            |  83%
# PRISM_ppt_stable_4kmD2_20230215_bil.zip already exists. Skipping downloading.
#   |===========================================================           |  84%
# PRISM_ppt_stable_4kmD2_20230216_bil.zip already exists. Skipping downloading.
#   |============================================================          |  86%
# PRISM_ppt_stable_4kmD2_20230217_bil.zip already exists. Skipping downloading.
#   |=============================================================         |  87%
# PRISM_ppt_stable_4kmD2_20230218_bil.zip already exists. Skipping downloading.
#   |==============================================================        |  89%
# PRISM_ppt_stable_4kmD2_20230219_bil.zip already exists. Skipping downloading.
#   |===============================================================       |  90%
# PRISM_ppt_stable_4kmD2_20230220_bil.zip already exists. Skipping downloading.
#   |================================================================      |  92%
# PRISM_ppt_stable_4kmD2_20230221_bil.zip already exists. Skipping downloading.
#   |==================================================================    |  94%
# PRISM_ppt_stable_4kmD2_20230222_bil.zip already exists. Skipping downloading.
#   |===================================================================   |  95%
# PRISM_ppt_stable_4kmD2_20230223_bil.zip already exists. Skipping downloading.
#   |====================================================================  |  97%
# PRISM_ppt_stable_4kmD2_20230224_bil.zip already exists. Skipping downloading.
#   |===================================================================== |  98%
# PRISM_ppt_stable_4kmD2_20230225_bil.zip already exists. Skipping downloading.
#   |======================================================================| 100%

# %%
# 1. Get all folders (you already did this)
folders <- prism_archive_ls()

# 2. Get full path to each .bil file
dl_dir <- prism_get_dl_dir()
bil_files <- file.path(dl_dir, folders, paste0(folders, ".bil"))

# 3. Load raster stack from actual .bil files
rasters <- stack(bil_files)

# 4. Define point of interestv

point <- SpatialPoints(cbind(-122.0308, 36.9741), 
                       proj4string = CRS("+proj=longlat +datum=WGS84"))

# 5. Extract values
values <- extract(rasters, point)

# 6. Extract dates from folder names
dates <- gsub("PRISM_ppt_stable_4kmD2_|_bil", "", basename(folders))
dates <- as.Date(dates, format = "%Y%m%d")

# 7. Build tidy data frame
data <- data.frame(Date = dates, Precipitation_mm = as.numeric(values))
data <- arrange(data, Date)
# Out:
# Warning message in .local(x, y, ...):
# “Transforming SpatialPoints to the crs of the Raster”

# %%
head(data)
summary(data)
# Out:
#   Date       Precipitation_mm
# 1 2022-12-25  0.0000
# 2 2022-12-26  0.0000
# 3 2022-12-27 38.4401
# 4 2022-12-28 30.2256
# 5 2022-12-29  3.6418
# 6 2022-12-30 32.1897
#       Date            Precipitation_mm
#  Min.   :2022-12-25   Min.   : 0.000
#  1st Qu.:2023-01-09   1st Qu.: 0.000
#  Median :2023-01-25   Median : 0.000
#  Mean   :2023-01-25   Mean   : 9.852
#  3rd Qu.:2023-02-09   3rd Qu.:14.156
#  Max.   :2023-02-25   Max.   :67.502
